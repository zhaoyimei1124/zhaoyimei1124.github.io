# %%
import pandas as pd

# %%
data1 = pd.read_csv("amazon_data1.csv")

# %%
data1
# Out:
#                                           product name        asin  \
# 0    BHAGIRATH Standard comfort Disposable Pollutio...  B085GL266P
# 1    SHOPPERMART urgical Face Mask Disposable - Pac...  B07YPSZK39
# 2    ShopyBucket Standard 3 PCS comfort Disposable ...  B0855V7MQ8
# 3    Ivaan Disposable Earloop Medical Face Masks Tw...  B082HDNJCP
# 4    TRENDING Anti-Pollution Dust Cotton Unisex Mou...  B084GTYK9V
# ..                                                 ...         ...
# 526  Mra Fashion N95 / PM 2.5 Anti Pollution Mask |...  B084KV4X8D
# 527        SG HEALTH N95 Kids pollution dust mask Pink  B07NDVKTXW
# 528  TrendzOn Anti-Virus 3Ply Disposable Face Masks...  B085M9ZKJK
# 529  Aptechdeals 5Pcs SURGICAL MASK with Ear Loop 3...  B085M6BN6Y
# 530  Aurum Creations Brand - Kodenipr Club® Disposa...  B07WCZNV94
#
#                                            product url     brand name  \
# 0    https://www.amazon.in/BHAGIRATH-Standard-Dispo...  Bhagirath fab
# ...

# %%
data1["brand name"].value_counts()
# Out:
# NV MART           19
# TrendzOn          19
# Antil's           18
# 3M                15
# MELVIS            14
#                   ..
# ASR SURGICAL       1
# MCP                1
# bosch-surgical     1
# Swadesh            1
# LIMBDA             1
# Name: brand name, Length: 237, dtype: int64
